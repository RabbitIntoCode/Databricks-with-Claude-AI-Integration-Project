# %% [markdown]
# Build a Medallion Architecture uisng Claude Code and Create a JOB in databricks to run all the notebooks in different layers based on the given data
#
# Bronze --> Raw Data
#
# Silver --> One big table combining the Cleaned data with different transformations
#
# Gold --> materialized Views based on client requirement

# %% [markdown]
# # Architecture

# %% [markdown]
# ![image_1778134437251.png](./image_1778134437251.png "image_1778134437251.png")
#
# Tech Stack required:
#
# ![image_1778134505718.png](./image_1778134505718.png "image_1778134505718.png")
#
# In those we will create an MCP(combining different Jobs) and provide the connection strings to Claude and LLM used underneeth this can be Sonet.
